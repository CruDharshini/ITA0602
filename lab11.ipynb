# %% [markdown]
# <a href="https://colab.research.google.com/github/CruDharshini/ITA0602/blob/main/lab11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Credit Score Classification

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# Create sample dataset
data = {
    'Income': [25000, 30000, 45000, 50000, 60000, 70000,
               20000, 35000, 55000, 80000, 40000, 65000],

    'Loan': [20000, 25000, 10000, 15000, 12000, 10000,
             25000, 20000, 15000, 8000, 18000, 9000],

    'Age': [22, 25, 30, 35, 40, 45,
            21, 28, 38, 50, 32, 42],

    'CreditScore': [
        'Poor', 'Poor', 'Average', 'Average', 'Good', 'Good',
        'Poor', 'Average', 'Good', 'Good', 'Average', 'Good'
    ]
}

# Convert data into DataFrame
df = pd.DataFrame(data)

print("Credit Score Dataset:")
print(df)

# Input features
X = df[['Income', 'Loan', 'Age']]

# Target
y = df['CreditScore']

# Split data into training and testing
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

# Create Decision Tree classifier
model = DecisionTreeClassifier(random_state=42)

# Train the model
model.fit(X_train, y_train)

# Predict test data
y_pred = model.predict(X_test)

# Display actual and predicted values
print("\nActual Values:")
print(y_test.values)

print("\nPredicted Values:")
print(y_pred)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)

print("\nAccuracy:", accuracy * 100, "%")

# Confusion Matrix
cm = confusion_matrix(
    y_test,
    y_pred,
    labels=['Poor', 'Average', 'Good']
)

print("\nConfusion Matrix:")
print(cm)

# Predict a new customer
new_customer = [[60000, 10000, 40]]

prediction = model.predict(new_customer)

print("\nNew Customer:")
print("Income = 60000")
print("Loan = 10000")
print("Age = 40")

print("\nPredicted Credit Score:", prediction[0])
# Out:
# Credit Score Dataset:
#     Income   Loan  Age CreditScore
# 0    25000  20000   22        Poor
# 1    30000  25000   25        Poor
# 2    45000  10000   30     Average
# 3    50000  15000   35     Average
# 4    60000  12000   40        Good
# 5    70000  10000   45        Good
# 6    20000  25000   21        Poor
# 7    35000  20000   28     Average
# 8    55000  15000   38        Good
# 9    80000   8000   50        Good
# 10   40000  18000   32     Average
# 11   65000   9000   42        Good
#
# Actual Values:
# ['Average' 'Good' 'Poor']
#
# Predicted Values:
# ['Average' 'Good' 'Poor']
#
# Accuracy: 100.0 %
#
# Confusion Matrix:
# [[1 0 0]
#  [0 1 0]
#  [0 0 1]]
#
# New Customer:
# Income = 60000
# Loan = 10000
# Age = 40
#
# Predicted Credit Score: Good
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
